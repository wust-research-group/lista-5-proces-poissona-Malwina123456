# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def poisson(T, lam):
    t = [0]
    S = 0

    while True:
        u = np.random.uniform()
        S = S - np.log(u) * (1 / lam)
        if S > T:
            break
        t.append(S)

    return t

# %%
def comp_poisson(T, lam):
    # N1 = N -t*lambda
    t = poisson(T, lam)
    steps = np.arange(0, T + 0.01, 0.01)
    kompensowany = np.zeros_like(time_steps)
    skoki = 0

    for i, t in enumerate(steps):
        while skoki < len(t) and t[skoki] <= t:
            skoki += 1
        kompensowany[i] = skoki - lam * t

    return steps, kompensowany

# %%
def plot(T, lambdas):
    plt.figure(figsize=(12, 6))
    for lam in lambdas:
        steps, kompensowany = comp_poisson(T, lam)
        plt.plot(steps, kompensowany, label=f"lambda = {lam}")

    plt.title("Trajektorie kompensowanego procesu Poissona")
    plt.xlabel("Czas")
    plt.ylabel("Wartość")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
T = 10
lambdas = [0.5, 1.0, 1.5, 2, 4]
plot_compensated_poissons(T, lambdas)
