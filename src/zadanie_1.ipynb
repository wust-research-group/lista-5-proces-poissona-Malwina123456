# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def poisson(T, lam):
    t = [0]
    S = 0

    while True:
        u = np.random.uniform()
        S = S - np.log(u) * (1 / lam)
        if S > T:
            break
        t.append(S)

    return t

# %%
def plot_poisson(T, lambdy):
    plt.figure(figsize=(12, 6))

    for lam in lambdy:
        t = poisson(T, lam)
        skoki = list(range(len(t)))  # range na listę
        plt.step(t + [T], skoki + [skoki[-1]], label=f"lambda = {lam}")

    plt.title(f"Trajektorie procesu Poissona")
    plt.xlabel("Czas")
    plt.ylabel("Proces Poissona")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
T = 5
lambdas = [0.3, 1.0, 1.5, 2, 4]

plot_poisson_processes(T, lambdas)
